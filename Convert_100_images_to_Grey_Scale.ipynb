# %% [markdown]
# <a href="https://colab.research.google.com/github/rkpassin132/python-opencv/blob/main/Convert_100_images_to_Grey_Scale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### "Convert 100 images to Grey Scale (b/w)" using OpenCV

# %%
# !pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import cv2
from google.colab.patches import cv2_imshow

image = cv2.imread('/content/images.jpeg')
cv2_imshow(image)
grayscale = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(grayscale)
# Out:
# <PIL.Image.Image image mode=RGB size=269x187 at 0x7FA23A4BF6D0>
# <PIL.Image.Image image mode=L size=269x187 at 0x7FA23A4BF6D0>
